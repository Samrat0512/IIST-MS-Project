# %%
import pandas as pd

# %%
agn_given = pd.read_csv("agn_list_with_radec.tsv", delimiter = '\t')
agn_from_csc = pd.read_csv("csc_results_june7_2022.tsv", header = 8, delimiter = '\t')
agn_crossmatched = pd.merge(agn_from_csc,agn_given, how = 'inner', on = 'name')

# %%
agn_crossmatched.to_csv('agn_crossmatched.tsv', sep = '\t')

# %%
agn_crossmatched
# Out:
#       usrid  separation  probability                   name acis_time  \
# 0         1        1.67         0.00  2CXO J095753.4+024735   49435.3
# 1         2        1.05         0.01  2CXO J163618.1+410038   73385.2
# 2         3        1.43         0.59  2CXO J222906.0-080251    7036.2
# 3         4        1.71         0.00  2CXO J082515.0+115752    5103.2
# 4         5        1.17         0.00  2CXO J151451.7+311654    4136.4
# ...     ...         ...          ...                    ...       ...
# 1494   1496        1.02         0.00  2CXO J090934.4+110549   34459.7
# 1495   1497        1.73         0.00  2CXO J022430.5-000038  101391.2
# 1496   1498        0.71         0.02  2CXO J105851.4+410644    7992.1
# 1497   1499        1.07         0.00  2CXO J211452.5+060742     56868
# 1498   1500        0.56         0.07  2CXO J100218.3+021053  292458.3
#
#       acis_num  hrc_num   hrc_time           ra        dec  ...        Rp  \
# ...
